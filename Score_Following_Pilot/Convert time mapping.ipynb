# %%
import numpy as np

# %%
data = [[0.0,0,3], [5.42000007629,1,3], [9.29200005531,2,3], [14.5799999237,3,3], [18.3329999447,4,3], [22.125,5,3], [26.1159999371,6,3], [30.4449999332,7,3], [34.5810000896,8,3], [39.7019999027,9,3], [44.4370000362,10,3], [48.8699998856,11,3], [51.8619999886,12,3], [56.4470000267,13,3], [63.7739999294,14,4], [70.0550000668,15,4], [75.9909999371,16,4], [80.6229999065,17,4], [87.8320000172,18,4], [92.3359999657,19,4], [95.9270000458,20,4], [100.21600008,21,4], [106.223999977,22,4], [112.009000063,23,4], [116.38499999,24,5], [121.960999966,25,5], [126.08100009,26,5], [129.865999937,27,5], [135.976999998,28,5], [140.170000076,29,5], [144.937999964,30,5], [151.322000027,31,5], [156.394999981,32,5], [166.388000011,33,5], [172.882999897,34,6], [179.10800004,35,6], [183.059999943,36,6], [186.987999916,37,6], [192.124000072,38,6], [196.30099988,39,6], [199.388999939,40,6], [205.516000032,41,6], [211.677000046,42,6], [216.813999891,43,6], [221.197000027,44,6], [227.822000027,45,6], [232.333999872,46,6]]

# %%
data = np.asarray(data)

# %%
data[:,0] = data[:,0]-1

# %%
data.tolist()
# Out:
# [[-1.0, 0.0, 3.0],
#  [4.42000007629, 1.0, 3.0],
#  [8.29200005531, 2.0, 3.0],
#  [13.5799999237, 3.0, 3.0],
#  [17.3329999447, 4.0, 3.0],
#  [21.125, 5.0, 3.0],
#  [25.1159999371, 6.0, 3.0],
#  [29.4449999332, 7.0, 3.0],
#  [33.5810000896, 8.0, 3.0],
#  [38.7019999027, 9.0, 3.0],
#  [43.4370000362, 10.0, 3.0],
#  [47.8699998856, 11.0, 3.0],
#  [50.8619999886, 12.0, 3.0],
#  [55.4470000267, 13.0, 3.0],
#  [62.7739999294, 14.0, 4.0],
#  [69.0550000668, 15.0, 4.0],
#  [74.9909999371, 16.0, 4.0],
#  [79.6229999065, 17.0, 4.0],
#  [86.8320000172, 18.0, 4.0],
#  [91.3359999657, 19.0, 4.0],
#  [94.9270000458, 20.0, 4.0],
#  [99.21600008, 21.0, 4.0],
#  [105.223999977, 22.0, 4.0],
#  [111.009000063, 23.0, 4.0],
#  [115.38499999, 24.0, 5.0],
#  [120.960999966, 25.0, 5.0],
#  [125.08100009, 26.0, 5.0],
#  [128.865999937, 27.0, 5.0],
#  [134.976999998, 28.0, 5.0],
#  [139.170000076, 29.0, 5.0],
#  [143.937999964, 30.0, 5.0],
#  [150.322000027, 31.0, 5.0],
#  [155.394999981, 32.0, 5.0],
# ...

# %%
data = [[6.74099993706], [11.5419998169], [16.7819998264], [19.5819997787], [24.4539999962], [28.646999836], [32.4869999886], [35.9019999504], [40.5509998798], [45.0869998932], [47.7039999962], [50.9279999733], [55.3349997997], [59.2559998035], [62.3359999657], [66.1679999828], [70.1209998131], [74.0639998913], [77.2319998741], [81.6169998646], [84.4729998112], [87.3699998856], [90.7289998531], [93.8809998035], [97.7379999161], [102.03399992]]

# %%
data = np.asarray(data)

# %%
data += 164

# %%
data
# Out:
# array([[ 170.74099994],
#        [ 175.54199982],
#        [ 180.78199983],
#        [ 183.58199978],
#        [ 188.454     ],
#        [ 192.64699984],
#        [ 196.48699999],
#        [ 199.90199995],
#        [ 204.55099988],
#        [ 209.08699989],
#        [ 211.704     ],
#        [ 214.92799997],
#        [ 219.3349998 ],
#        [ 223.2559998 ],
#        [ 226.33599997],
#        [ 230.16799998],
#        [ 234.12099981],
#        [ 238.06399989],
#        [ 241.23199987],
#        [ 245.61699986],
#        [ 248.47299981],
#        [ 251.36999989],
#        [ 254.72899985],
#        [ 257.8809998 ],
#        [ 261.73799992],
#        [ 266.03399992]])
