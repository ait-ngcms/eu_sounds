# %%
import os
import glob

import numpy as np
import pandas as pd

# %%
FEATURE_DIR   = "E:/Data/MIR/EU_SOUNDS_FEATURES"
HDFSTORE_PATH = "E:/Data/MIR/EU_SOUNDS_FEATURES"
HDFSTORE_NAME = "HDFStore"

# %%
store_path = "%s/%s.h5" % (HDFSTORE_PATH,HDFSTORE_NAME)
store = pd.HDFStore(store_path)

# %%
store.close()

# %%
i = 1

data = {}

for feat_set in ['trh', 'rp', 'mvd', 'ssd', 'tssd', 'rh', 'filename']:
    data[feat_set] = []

for dir_name in glob.glob(os.path.join(FEATURE_DIR, "*")):
    
    src_path = dir_name.replace("\\","/")
    
    for npz_name in glob.glob(os.path.join(src_path, "*.npz")):
        
        try:
            
            npz = np.load(npz_name.replace("\\","/"))
            
            for feat_set in ['trh', 'rp', 'mvd', 'ssd', 'tssd', 'rh']:
                data[feat_set].append(npz[feat_set])
                
            data['filename'].append(npz_name)
            
            i += 1
            
            if i % 10000 == 0:
                print i
            
        except Exception as e:
            
            print npz_name, e
            i += 1
            
        finally:
            
            npz.close()
        
        #if i > 100:
        #    break
        
        
    #if i > 100:
    #    break
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678196.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678196.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678197.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678197.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678198.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678198.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678199.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678199.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678200.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678200.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678201.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678201.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678202.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678202.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678203.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678203.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678204.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678204.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678205.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678205.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678206.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678206.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678207.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678207.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678208.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678208.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678209.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678209.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678210.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678210.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678220.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678220.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678221.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678221.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678222.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678222.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678223.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678223.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678224.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678224.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678225.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678225.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678226.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678226.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678227.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678227.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678228.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678228.mp3.npz' as a pickle
# E:/Data/MIR/EU_SOUNDS_FEATURES/2023601\oai_eu_dismarc_BISM_ES6100678229.mp3.npz Failed to interpret file 'E:/Data/MIR/EU_SOUNDS_FEATURES/2023601/oai_eu_dismarc_BISM_ES6100678229.mp3.npz' as a pickle
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000

# %%
#for feat_set in ['trh', 'rp', 'mvd', 'ssd', 'tssd', 'rh']:
np.savez("E:/Data/MIR/EU_SOUNDS_FEATURES/combined_features",
         trh  = np.asarray(data['trh']), 
         rp   = np.asarray(data['rp']), 
         mvd  = np.asarray(data['mvd']), 
         ssd  = np.asarray(data['ssd']), 
         tssd = np.asarray(data['tssd']), 
         rh   = np.asarray(data['rh']),
         filenames = np.asarray(data['filename']))
